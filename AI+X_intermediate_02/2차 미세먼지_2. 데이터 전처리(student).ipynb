# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/MyDrive/AI+X_middle_02')

# %%
# 필요한 라이브러리 설치 및 임포트
import pandas as pd
import datetime

# %% [markdown]
# ---

# %% [markdown]
# # [Step 2] 데이터 전처리

# %% [markdown]
# #### **<span style="color:blue">[2-0] air_21, air_22, weather_21, weather_22 데이터 로딩</span>**

# %%
# 데이터 로딩
air_21 = pd.read_csv('air_2021.csv')
air_21.head()
# Out:
#    Unnamed: 0      지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3  \
# 0           0  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002
# 1           1  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002
# 2           2  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002
# 3           3  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002
# 4           4  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003
#
#      NO2  PM10  PM25                주소
# 0  0.039  31.0  18.0  서울 종로구 종로35가길 19
# 1  0.035  27.0  16.0  서울 종로구 종로35가길 19
# 2  0.033  28.0  18.0  서울 종로구 종로35가길 19
# 3  0.030  26.0  16.0  서울 종로구 종로35가길 19
# 4  0.026  26.0  16.0  서울 종로구 종로35가길 19

# %%
air_22 = pd.read_csv('air_2022.csv')
air_22.head()
# Out:
#    Unnamed: 0      지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3  \
# 0           0  서울 종로구  도시대기  111123  종로구  2022010101  0.003  0.4  0.026
# 1           1  서울 종로구  도시대기  111123  종로구  2022010102  0.003  0.4  0.022
# 2           2  서울 종로구  도시대기  111123  종로구  2022010103  0.003  0.5  0.014
# 3           3  서울 종로구  도시대기  111123  종로구  2022010104  0.003  0.5  0.016
# 4           4  서울 종로구  도시대기  111123  종로구  2022010105  0.003  0.5  0.005
#
#      NO2  PM10  PM25                주소
# 0  0.016  23.0  12.0  서울 종로구 종로35가길 19
# 1  0.020  20.0   9.0  서울 종로구 종로35가길 19
# 2  0.028  20.0   9.0  서울 종로구 종로35가길 19
# 3  0.027  19.0  10.0  서울 종로구 종로35가길 19
# 4  0.040  24.0  11.0  서울 종로구 종로35가길 19

# %%
weather_21 = pd.read_csv('weather_2021.csv', encoding='cp949')
weather_21.head()
# Out:
#     지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  108  서울  2021-01-01 01:00    -8.7       NaN      NaN        NaN      2.4
# 1  108  서울  2021-01-01 02:00    -9.1       NaN      NaN        NaN      1.6
# 2  108  서울  2021-01-01 03:00    -9.3       NaN      NaN        NaN      1.1
# 3  108  서울  2021-01-01 04:00    -9.3       NaN      NaN        NaN      0.3
# 4  108  서울  2021-01-01 05:00    -9.7       NaN      NaN        NaN      1.9
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       NaN     270.0  ...          NaN     2000           NaN        NaN
# 1       NaN     270.0  ...          NaN     2000           NaN        NaN
# 2       NaN     250.0  ...          NaN     2000           NaN        NaN
# 3       NaN       0.0  ...          NaN     2000           NaN        NaN
# 4       NaN      20.0  ...          NaN     2000           NaN        NaN
#
#    지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  \
# 0      -6.9         NaN          -1.0           -0.8            0.3
# 1      -7.1         NaN          -1.1           -0.8            0.3
# 2      -7.3         NaN          -1.2           -0.9            0.3
# 3      -7.5         NaN          -1.3           -1.0            0.2
# 4      -7.6         NaN          -1.3           -1.0            0.2
#
#    30cm 지중온도(°C)
# 0            1.6
# 1            1.6
# 2            1.6
# 3            1.5
# 4            1.5
#
# [5 rows x 38 columns]

# %%
weather_22 = pd.read_csv('weather_2022.csv', encoding='cp949')
weather_22.head()
# Out:
#     지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  108  서울  2022-01-01 00:00    -8.5       NaN      NaN        NaN      1.9
# 1  108  서울  2022-01-01 01:00    -9.2       NaN      NaN        NaN      1.8
# 2  108  서울  2022-01-01 02:00    -9.5       NaN      NaN        NaN      1.2
# 3  108  서울  2022-01-01 03:00    -9.3       NaN      NaN        NaN      1.4
# 4  108  서울  2022-01-01 04:00    -9.6       NaN      NaN        NaN      1.7
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       NaN       320  ...          NaN     2000           NaN        NaN
# 1       NaN       270  ...          NaN     2000           NaN        NaN
# 2       NaN       270  ...          NaN     2000           NaN        NaN
# 3       NaN       290  ...          NaN     2000           NaN        NaN
# 4       NaN       340  ...          NaN     2000           NaN        NaN
#
#    지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  \
# 0      -7.0         NaN          -1.0           -1.0           -0.2
# 1      -7.2         NaN          -1.1           -1.1           -0.2
# 2      -7.5         NaN          -1.3           -1.2           -0.2
# 3      -7.6         NaN          -1.4           -1.2           -0.2
# 4      -7.6         NaN          -1.4           -1.3           -0.3
#
#    30cm 지중온도(°C)
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#
# [5 rows x 38 columns]

# %% [markdown]
# #### **<span style="color:blue">[2-1] air_21, air_22 의 '측정일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * air_21, air_22 의 '측정일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경
# * 참고: 미세먼지 데이터는 1시-24시, 날씨 데이터는 0시-23시로 구성되어 있습니다. [2-5]에서 미세먼지와 날씨 데이터를 time 기준으로 합치려면 날씨 기준이 동일해야 합니다. 미세먼지 데이터에서 time 변수 생성 시 이를 미리 고려(예:측정일시 값 -1)하세요.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
air_21['time'] = air_21['측정일시'] - 1
air_21['time'] = pd.to_datetime(air_21['time'], format='%Y%m%d%H')
air_21['time'].head()
# Out:
# 0   2021-10-01 00:00:00
# 1   2021-10-01 01:00:00
# 2   2021-10-01 02:00:00
# 3   2021-10-01 03:00:00
# 4   2021-10-01 04:00:00
# Name: time, dtype: datetime64[ns]

# %%
air_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8760 non-null   int64
#  1   지역          8760 non-null   object
#  2   망           8760 non-null   object
#  3   측정소코드       8760 non-null   int64
#  4   측정소명        8760 non-null   object
#  5   측정일시        8760 non-null   int64
#  6   SO2         8648 non-null   float64
#  7   CO          8680 non-null   float64
#  8   O3          8663 non-null   float64
#  9   NO2         8680 non-null   float64
#  10  PM10        8655 non-null   float64
#  11  PM25        8663 non-null   float64
#  12  주소          8760 non-null   object
#  13  time        8760 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(3), object(4)
# memory usage: 958.2+ KB

# %%
air_22['time'] = air_22['측정일시'] - 1
air_22['time'] = pd.to_datetime(air_22['time'], format='%Y%m%d%H')
air_22['time'].head()
# Out:
# 0   2022-01-01 00:00:00
# 1   2022-01-01 01:00:00
# 2   2022-01-01 02:00:00
# 3   2022-01-01 03:00:00
# 4   2022-01-01 04:00:00
# Name: time, dtype: datetime64[ns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-2] weather_21, weather_22 의 '일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * weather_21, weather_22 의 '일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
weather_21['time'] = pd.to_datetime(weather_21['일시'])
weather_21['time'].head()
# Out:
# 0   2021-01-01 01:00:00
# 1   2021-01-01 02:00:00
# 2   2021-01-01 03:00:00
# 3   2021-01-01 04:00:00
# 4   2021-01-01 05:00:00
# Name: time, dtype: datetime64[ns]

# %%
weather_21['time'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8759 entries, 0 to 8758
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 8759 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 68.6 KB

# %%
weather_22['time'] = pd.to_datetime(weather_22['일시'])
weather_22['time'].head()
# Out:
# 0   2022-01-01 00:00:00
# 1   2022-01-01 01:00:00
# 2   2022-01-01 02:00:00
# 3   2022-01-01 03:00:00
# 4   2022-01-01 04:00:00
# Name: time, dtype: datetime64[ns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-3] 'time' 기준으로 데이터 합치기</span>**

# %% [markdown]
# * 미세먼지 데이터와 날씨 데이터를 'time' 기준으로 합쳐보세요.
# * df_21에는 'time' 기준으로 21년도 미세먼지, 날씨 데이터를 합쳐보세요.
# * df_22에는 'time' 기준으로 22년도 미세먼지, 날씨 데이터를 합쳐보세요.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
df_21 = pd.merge(air_21, weather_21, on='time')
df_21.head()
# Out:
#    Unnamed: 0      지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3  \
# 0           0  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002
# 1           1  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002
# 2           2  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002
# 3           3  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002
# 4           4  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003
#
#      NO2  ...  최저운고(100m )  시정(10m) 지면상태(지면상태코드) 현상번호(국내식)  지면온도(°C)  \
# 0  0.039  ...          NaN     2000          NaN       NaN      17.8
# 1  0.035  ...          NaN     2000          NaN       NaN      17.4
# 2  0.033  ...          NaN     2000          NaN       NaN      17.2
# 3  0.030  ...          NaN     2000          NaN       NaN      17.0
# 4  0.026  ...          NaN     2000          NaN       NaN      16.5
#
#   지면온도 QC플래그 5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 0        NaN         22.3           22.3           22.7           22.9
# 1        NaN         22.1           22.0           22.5           22.9
# 2        NaN         21.8           21.8           22.4           22.8
# 3        NaN         21.6           21.6           22.2           22.8
# 4        NaN         21.3           21.4           22.0           22.7
#
# [5 rows x 52 columns]

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8759 entries, 0 to 8758
# Data columns (total 52 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8759 non-null   int64
#  1   지역             8759 non-null   object
#  2   망              8759 non-null   object
#  3   측정소코드          8759 non-null   int64
#  4   측정소명           8759 non-null   object
#  5   측정일시           8759 non-null   int64
#  6   SO2            8647 non-null   float64
#  7   CO             8679 non-null   float64
#  8   O3             8662 non-null   float64
#  9   NO2            8679 non-null   float64
#  10  PM10           8654 non-null   float64
#  11  PM25           8662 non-null   float64
#  12  주소             8759 non-null   object
#  13  time           8759 non-null   datetime64[ns]
#  14  지점             8759 non-null   int64
#  15  지점명            8759 non-null   object
#  16  일시             8759 non-null   object
#  17  기온(°C)         8759 non-null   float64
#  18  기온 QC플래그       0 non-null      float64
#  19  강수량(mm)        949 non-null    float64
#  20  강수량 QC플래그      1763 non-null   float64
#  21  풍속(m/s)        8757 non-null   float64
#  22  풍속 QC플래그       2 non-null      float64
#  23  풍향(16방위)       8757 non-null   float64
#  24  풍향 QC플래그       2 non-null      float64
#  25  습도(%)          8759 non-null   int64
#  26  습도 QC플래그       0 non-null      float64
#  27  증기압(hPa)       8759 non-null   float64
#  28  이슬점온도(°C)      8759 non-null   float64
#  29  현지기압(hPa)      8759 non-null   float64
#  30  현지기압 QC플래그     0 non-null      float64
#  31  해면기압(hPa)      8759 non-null   float64
#  32  해면기압 QC플래그     0 non-null      float64
#  33  일조(hr)         4791 non-null   float64
#  34  일조 QC플래그       3968 non-null   float64
#  35  일사(MJ/m2)      4791 non-null   float64
#  36  일사 QC플래그       3968 non-null   float64
#  37  적설(cm)         379 non-null    float64
#  38  3시간신적설(cm)     29 non-null     float64
#  39  전운량(10분위)      8757 non-null   float64
#  40  중하층운량(10분위)    8759 non-null   int64
#  41  운형(운형약어)       4947 non-null   object
#  42  최저운고(100m )    4547 non-null   float64
#  43  시정(10m)        8759 non-null   int64
#  44  지면상태(지면상태코드)   0 non-null      float64
#  45  현상번호(국내식)      2125 non-null   float64
#  46  지면온도(°C)       8754 non-null   float64
#  47  지면온도 QC플래그     24 non-null     float64
#  48  5cm 지중온도(°C)   8754 non-null   float64
#  49  10cm 지중온도(°C)  8754 non-null   float64
#  50  20cm 지중온도(°C)  8754 non-null   float64
#  51  30cm 지중온도(°C)  8754 non-null   float64
# dtypes: datetime64[ns](1), float64(37), int64(7), object(7)
# memory usage: 3.5+ MB

# %%
df_22 = pd.merge(air_22, weather_22, on='time')
df_22.head()
# Out:
#    Unnamed: 0      지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3  \
# 0           0  서울 종로구  도시대기  111123  종로구  2022010101  0.003  0.4  0.026
# 1           1  서울 종로구  도시대기  111123  종로구  2022010102  0.003  0.4  0.022
# 2           2  서울 종로구  도시대기  111123  종로구  2022010103  0.003  0.5  0.014
# 3           3  서울 종로구  도시대기  111123  종로구  2022010104  0.003  0.5  0.016
# 4           4  서울 종로구  도시대기  111123  종로구  2022010105  0.003  0.5  0.005
#
#      NO2  ...  최저운고(100m )  시정(10m) 지면상태(지면상태코드) 현상번호(국내식)  지면온도(°C)  \
# 0  0.016  ...          NaN     2000          NaN       NaN      -7.0
# 1  0.020  ...          NaN     2000          NaN       NaN      -7.2
# 2  0.028  ...          NaN     2000          NaN       NaN      -7.5
# 3  0.027  ...          NaN     2000          NaN       NaN      -7.6
# 4  0.040  ...          NaN     2000          NaN       NaN      -7.6
#
#   지면온도 QC플래그 5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 0        NaN         -1.0           -1.0           -0.2            1.0
# 1        NaN         -1.1           -1.1           -0.2            1.0
# 2        NaN         -1.3           -1.2           -0.2            1.0
# 3        NaN         -1.4           -1.2           -0.2            1.0
# 4        NaN         -1.4           -1.3           -0.3            1.0
#
# [5 rows x 52 columns]

# %%
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 52 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2160 non-null   int64
#  1   지역             2160 non-null   object
#  2   망              2160 non-null   object
#  3   측정소코드          2160 non-null   int64
#  4   측정소명           2160 non-null   object
#  5   측정일시           2160 non-null   int64
#  6   SO2            2139 non-null   float64
#  7   CO             2139 non-null   float64
#  8   O3             2139 non-null   float64
#  9   NO2            2139 non-null   float64
#  10  PM10           2122 non-null   float64
#  11  PM25           2135 non-null   float64
#  12  주소             2160 non-null   object
#  13  time           2160 non-null   datetime64[ns]
#  14  지점             2160 non-null   int64
#  15  지점명            2160 non-null   object
#  16  일시             2160 non-null   object
#  17  기온(°C)         2160 non-null   float64
#  18  기온 QC플래그       0 non-null      float64
#  19  강수량(mm)        81 non-null     float64
#  20  강수량 QC플래그      382 non-null    float64
#  21  풍속(m/s)        2160 non-null   float64
#  22  풍속 QC플래그       0 non-null      float64
#  23  풍향(16방위)       2160 non-null   int64
#  24  풍향 QC플래그       0 non-null      float64
#  25  습도(%)          2160 non-null   int64
#  26  습도 QC플래그       0 non-null      float64
#  27  증기압(hPa)       2160 non-null   float64
#  28  이슬점온도(°C)      2160 non-null   float64
#  29  현지기압(hPa)      2160 non-null   float64
#  30  현지기압 QC플래그     0 non-null      float64
#  31  해면기압(hPa)      2160 non-null   float64
#  32  해면기압 QC플래그     0 non-null      float64
#  33  일조(hr)         1071 non-null   float64
#  34  일조 QC플래그       1089 non-null   float64
#  35  일사(MJ/m2)      1071 non-null   float64
#  36  일사 QC플래그       1089 non-null   float64
#  37  적설(cm)         140 non-null    float64
#  38  3시간신적설(cm)     15 non-null     float64
#  39  전운량(10분위)      2160 non-null   int64
#  40  중하층운량(10분위)    2160 non-null   int64
#  41  운형(운형약어)       939 non-null    object
#  42  최저운고(100m )    743 non-null    float64
#  43  시정(10m)        2160 non-null   int64
#  44  지면상태(지면상태코드)   0 non-null      float64
#  45  현상번호(국내식)      418 non-null    float64
#  46  지면온도(°C)       2160 non-null   float64
#  47  지면온도 QC플래그     7 non-null      float64
#  48  5cm 지중온도(°C)   2160 non-null   float64
#  49  10cm 지중온도(°C)  2160 non-null   float64
#  50  20cm 지중온도(°C)  2160 non-null   float64
#  51  30cm 지중온도(°C)  2160 non-null   float64
# dtypes: datetime64[ns](1), float64(35), int64(9), object(7)
# memory usage: 877.6+ KB

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-4] 사용하지 않을 변수 제거</span>**

# %% [markdown]
# * 머신러닝에 사용하지 않을 변수들을 제거해줍니다.
# * df_21, df_22에 사용할 변수들만 넣어보세요.

# %%
drop_columns = ['지역', '망', '측정소코드', '측정소명', '주소', '지점', '지점명',
                '일시', '측정일시', '운형(운형약어)', '최저운고(100m )',
                '기온 QC플래그', '강수량 QC플래그', '풍속 QC플래그',
                '풍향 QC플래그', '습도 QC플래그', '현지기압 QC플래그', '일조 QC플래그',
                '해면기압 QC플래그', '일사 QC플래그', '지면온도 QC플래그',
                '지면상태(지면상태코드)', '현상번호(국내식)', '3시간신적설(cm)']

df_21 = df_21.drop(columns=drop_columns)
df_22 = df_22.drop(columns=drop_columns)

# %%
# time 변수를 index로 세팅
df_21 = df_21.set_index('time')
df_22 = df_22.set_index('time')
df_21.head()
# Out:
#                      Unnamed: 0    SO2   CO     O3    NO2  PM10  PM25  기온(°C)  \
# time
# 2021-10-01 00:00:00           0  0.003  0.6  0.002  0.039  31.0  18.0    19.2
# 2021-10-01 01:00:00           1  0.003  0.6  0.002  0.035  27.0  16.0    18.7
# 2021-10-01 02:00:00           2  0.003  0.6  0.002  0.033  28.0  18.0    18.3
# 2021-10-01 03:00:00           3  0.003  0.6  0.002  0.030  26.0  16.0    17.7
# 2021-10-01 04:00:00           4  0.003  0.5  0.003  0.026  26.0  16.0    17.4
#
#                      강수량(mm)  풍속(m/s)  ...  일사(MJ/m2)  적설(cm)  전운량(10분위)  \
# time                                   ...
# 2021-10-01 00:00:00      NaN      1.3  ...        NaN     NaN        0.0
# 2021-10-01 01:00:00      NaN      1.0  ...        NaN     NaN        0.0
# 2021-10-01 02:00:00      NaN      0.3  ...        NaN     NaN        0.0
# 2021-10-01 03:00:00      NaN      2.0  ...        NaN     NaN        0.0
# 2021-10-01 04:00:00      NaN      1.0  ...        NaN     NaN        0.0
#
#                      중하층운량(10분위)  시정(10m)  지면온도(°C)  5cm 지중온도(°C)  \
# time
# 2021-10-01 00:00:00            0     2000      17.8          22.3
# 2021-10-01 01:00:00            0     2000      17.4          22.1
# 2021-10-01 02:00:00            0     2000      17.2          21.8
# 2021-10-01 03:00:00            0     2000      17.0          21.6
# 2021-10-01 04:00:00            0     2000      16.5          21.3
#
#                      10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# time
# 2021-10-01 00:00:00           22.3           22.7           22.9
# 2021-10-01 01:00:00           22.0           22.5           22.9
# 2021-10-01 02:00:00           21.8           22.4           22.8
# 2021-10-01 03:00:00           21.6           22.2           22.8
# 2021-10-01 04:00:00           21.4           22.0           22.7
#
# [5 rows x 27 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-5] 변수들의 결측치 처리</span>**

# %%
# df_21, df_22의 결측치 확인
df_21.isnull().sum()
# Out:
# Unnamed: 0          0
# SO2               112
# CO                 80
# O3                 97
# NO2                80
# PM10              105
# PM25               97
# 기온(°C)              0
# 강수량(mm)          7810
# 풍속(m/s)             2
# 풍향(16방위)            2
# 습도(%)               0
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 해면기압(hPa)           0
# 일조(hr)           3968
# 일사(MJ/m2)        3968
# 적설(cm)           8380
# 전운량(10분위)           2
# 중하층운량(10분위)         0
# 시정(10m)             0
# 지면온도(°C)            5
# 5cm 지중온도(°C)        5
# 10cm 지중온도(°C)       5
# 20cm 지중온도(°C)       5
# 30cm 지중온도(°C)       5
# dtype: int64

# %%
df_22.isnull().sum()
# Out:
# Unnamed: 0          0
# SO2                21
# CO                 21
# O3                 21
# NO2                21
# PM10               38
# PM25               25
# 기온(°C)              0
# 강수량(mm)          2079
# 풍속(m/s)             0
# 풍향(16방위)            0
# 습도(%)               0
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 해면기압(hPa)           0
# 일조(hr)           1089
# 일사(MJ/m2)        1089
# 적설(cm)           2020
# 전운량(10분위)           0
# 중하층운량(10분위)         0
# 시정(10m)             0
# 지면온도(°C)            0
# 5cm 지중온도(°C)        0
# 10cm 지중온도(°C)       0
# 20cm 지중온도(°C)       0
# 30cm 지중온도(°C)       0
# dtype: int64

# %%
# df_21, df_22의 변수 중 '강수량(mm)'의 결측치를 처리
df_21['강수량(mm)'] = df_21['강수량(mm)'].fillna(0)
df_22['강수량(mm)'] = df_22['강수량(mm)'].fillna(0)

# %%
# df_21, df_22의 남은 결측치를 처리
df_21['적설(cm)'] = df_21['적설(cm)'].fillna(0)
df_22['적설(cm)'] = df_22['적설(cm)'].fillna(0)

# %%
df_21['일조(hr)'] = df_21['일조(hr)'].fillna(0)
df_22['일조(hr)'] = df_22['일조(hr)'].fillna(0)

# %%
df_21['일사(MJ/m2)'] = df_21['일사(MJ/m2)'].fillna(0)
df_22['일사(MJ/m2)'] = df_22['일사(MJ/m2)'].fillna(0)

# %%
# df_21, df_22의 결측치 재확인
df_21.isnull().sum()
# Out:
# Unnamed: 0         0
# SO2              112
# CO                80
# O3                97
# NO2               80
# PM10             105
# PM25              97
# 기온(°C)             0
# 강수량(mm)            0
# 풍속(m/s)            2
# 풍향(16방위)           2
# 습도(%)              0
# 증기압(hPa)           0
# 이슬점온도(°C)          0
# 현지기압(hPa)          0
# 해면기압(hPa)          0
# 일조(hr)             0
# 일사(MJ/m2)          0
# 적설(cm)             0
# 전운량(10분위)          2
# 중하층운량(10분위)        0
# 시정(10m)            0
# 지면온도(°C)           5
# 5cm 지중온도(°C)       5
# 10cm 지중온도(°C)      5
# 20cm 지중온도(°C)      5
# 30cm 지중온도(°C)      5
# dtype: int64

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8759 entries, 2021-10-01 00:00:00 to 2021-09-30 23:00:00
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8759 non-null   int64
#  1   SO2            8647 non-null   float64
#  2   CO             8679 non-null   float64
#  3   O3             8662 non-null   float64
#  4   NO2            8679 non-null   float64
#  5   PM10           8654 non-null   float64
#  6   PM25           8662 non-null   float64
#  7   기온(°C)         8759 non-null   float64
#  8   강수량(mm)        8759 non-null   float64
#  9   풍속(m/s)        8757 non-null   float64
#  10  풍향(16방위)       8757 non-null   float64
#  11  습도(%)          8759 non-null   int64
#  12  증기압(hPa)       8759 non-null   float64
#  13  이슬점온도(°C)      8759 non-null   float64
#  14  현지기압(hPa)      8759 non-null   float64
#  15  해면기압(hPa)      8759 non-null   float64
#  16  일조(hr)         8759 non-null   float64
#  17  일사(MJ/m2)      8759 non-null   float64
#  18  적설(cm)         8759 non-null   float64
#  19  전운량(10분위)      8757 non-null   float64
#  20  중하층운량(10분위)    8759 non-null   int64
#  21  시정(10m)        8759 non-null   int64
#  22  지면온도(°C)       8754 non-null   float64
#  23  5cm 지중온도(°C)   8754 non-null   float64
#  24  10cm 지중온도(°C)  8754 non-null   float64
#  25  20cm 지중온도(°C)  8754 non-null   float64
#  26  30cm 지중온도(°C)  8754 non-null   float64
# dtypes: float64(23), int64(4)
# memory usage: 1.9 MB

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-6] 전일 같은 시간 변수 추가</span>**

# %% [markdown]
# * 모델링에 유용한 변수로 전일 같은 시간(24시간 전) 미세먼지 농도 변수를 추가합니다.
# * 시계열 데이터 처리를 위한 shift 연산을 참고하세요.

# %%
# df_21, df_22의 index(time)를 month, day, hour 로 쪼개기 (year는 필요 없음)
df_21['month'] = df_21.index.month
df_21['day'] = df_21.index.day
df_21['hour'] = df_21.index.hour

# %%
df_22['month'] = df_22.index.month
df_22['day'] = df_22.index.day
df_22['hour'] = df_22.index.hour

# %%
# df_21, df_22에 전일 같은 시간 미세먼지 농도 변수(PM10_lag1) 추가
# 전일 같은 시간은 24시간 전 입니다.
df_21['PM10_lag1'] = df_21['PM10'].shift(24)
df_22['PM10_lag1'] = df_22['PM10'].shift(24)

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8759 entries, 2021-10-01 00:00:00 to 2021-09-30 23:00:00
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8759 non-null   int64
#  1   SO2            8647 non-null   float64
#  2   CO             8679 non-null   float64
#  3   O3             8662 non-null   float64
#  4   NO2            8679 non-null   float64
#  5   PM10           8654 non-null   float64
#  6   PM25           8662 non-null   float64
#  7   기온(°C)         8759 non-null   float64
#  8   강수량(mm)        8759 non-null   float64
#  9   풍속(m/s)        8757 non-null   float64
#  10  풍향(16방위)       8757 non-null   float64
#  11  습도(%)          8759 non-null   int64
#  12  증기압(hPa)       8759 non-null   float64
#  13  이슬점온도(°C)      8759 non-null   float64
#  14  현지기압(hPa)      8759 non-null   float64
#  15  해면기압(hPa)      8759 non-null   float64
#  16  일조(hr)         8759 non-null   float64
#  17  일사(MJ/m2)      8759 non-null   float64
#  18  적설(cm)         8759 non-null   float64
#  19  전운량(10분위)      8757 non-null   float64
#  20  중하층운량(10분위)    8759 non-null   int64
#  21  시정(10m)        8759 non-null   int64
#  22  지면온도(°C)       8754 non-null   float64
#  23  5cm 지중온도(°C)   8754 non-null   float64
#  24  10cm 지중온도(°C)  8754 non-null   float64
#  25  20cm 지중온도(°C)  8754 non-null   float64
#  26  30cm 지중온도(°C)  8754 non-null   float64
#  27  month          8759 non-null   int32
#  28  day            8759 non-null   int32
#  29  hour           8759 non-null   int32
#  30  PM10_lag1      8630 non-null   float64
# dtypes: float64(24), int32(3), int64(4)
# memory usage: 2.0 MB

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-7] t+1 시점의 미세먼지 농도 데이터 생성</span>**

# %% [markdown]
# * t+1 시점은 1시간 후 입니다.
# * t+1 시점의 미세먼지 농도 변수를 생성하세요.
# * t+1 시점의 미세먼지 농도는 머신러닝 모델을 통해 예측하려는 y값(target) 입니다.

# %%
# df_21, df_22에 t+1 시점 변수(PM10_1) 추가
df_21['PM10_1'] = df_21['PM10'].shift(-1)
df_22['PM10_1'] = df_22['PM10'].shift(-1)

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8759 entries, 2021-10-01 00:00:00 to 2021-09-30 23:00:00
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8759 non-null   int64
#  1   SO2            8647 non-null   float64
#  2   CO             8679 non-null   float64
#  3   O3             8662 non-null   float64
#  4   NO2            8679 non-null   float64
#  5   PM10           8654 non-null   float64
#  6   PM25           8662 non-null   float64
#  7   기온(°C)         8759 non-null   float64
#  8   강수량(mm)        8759 non-null   float64
#  9   풍속(m/s)        8757 non-null   float64
#  10  풍향(16방위)       8757 non-null   float64
#  11  습도(%)          8759 non-null   int64
#  12  증기압(hPa)       8759 non-null   float64
#  13  이슬점온도(°C)      8759 non-null   float64
#  14  현지기압(hPa)      8759 non-null   float64
#  15  해면기압(hPa)      8759 non-null   float64
#  16  일조(hr)         8759 non-null   float64
#  17  일사(MJ/m2)      8759 non-null   float64
#  18  적설(cm)         8759 non-null   float64
#  19  전운량(10분위)      8757 non-null   float64
#  20  중하층운량(10분위)    8759 non-null   int64
#  21  시정(10m)        8759 non-null   int64
#  22  지면온도(°C)       8754 non-null   float64
#  23  5cm 지중온도(°C)   8754 non-null   float64
#  24  10cm 지중온도(°C)  8754 non-null   float64
#  25  20cm 지중온도(°C)  8754 non-null   float64
#  26  30cm 지중온도(°C)  8754 non-null   float64
#  27  month          8759 non-null   int32
#  28  day            8759 non-null   int32
#  29  hour           8759 non-null   int32
#  30  PM10_lag1      8630 non-null   float64
#  31  PM10_1         8653 non-null   float64
# dtypes: float64(25), int32(3), int64(4)
# memory usage: 2.1 MB

# %%
# 결측치가 있다면 처리
df_21 = df_21.dropna()
df_22 = df_22.dropna()
df_21.head()
# Out:
#                      Unnamed: 0    SO2   CO     O3    NO2  PM10  PM25  기온(°C)  \
# time
# 2021-10-02 00:00:00          24  0.002  0.3  0.046  0.012  10.0   7.0    17.0
# 2021-10-02 01:00:00          25  0.003  0.3  0.041  0.014   9.0   6.0    16.6
# 2021-10-02 02:00:00          26  0.003  0.3  0.039  0.015   9.0   8.0    16.8
# 2021-10-02 03:00:00          27  0.003  0.4  0.029  0.016  10.0   7.0    16.6
# 2021-10-02 04:00:00          28  0.002  0.4  0.029  0.016  11.0   9.0    16.7
#
#                      강수량(mm)  풍속(m/s)  ...  지면온도(°C)  5cm 지중온도(°C)  \
# time                                   ...
# 2021-10-02 00:00:00      0.6      2.9  ...      17.8          21.7
# 2021-10-02 01:00:00      0.0      1.8  ...      17.6          21.6
# 2021-10-02 02:00:00      0.0      0.9  ...      17.9          21.4
# 2021-10-02 03:00:00      0.0      0.9  ...      17.7          21.3
# 2021-10-02 04:00:00      0.0      1.3  ...      17.4          21.2
#
#                      10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)  month  day  \
# time
# 2021-10-02 00:00:00           21.8           22.6           23.0     10    2
# 2021-10-02 01:00:00           21.6           22.4           22.9     10    2
# 2021-10-02 02:00:00           21.4           22.2           22.8     10    2
# 2021-10-02 03:00:00           21.3           22.0           22.7     10    2
# 2021-10-02 04:00:00           21.2           21.9           22.6     10    2
#
#                      hour  PM10_lag1  PM10_1
# time
# 2021-10-02 00:00:00     0       31.0     9.0
# 2021-10-02 01:00:00     1       27.0     9.0
# 2021-10-02 02:00:00     2       28.0    10.0
# 2021-10-02 03:00:00     3       26.0    11.0
# 2021-10-02 04:00:00     4       26.0    11.0
#
# [5 rows x 32 columns]

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8431 entries, 2021-10-02 00:00:00 to 2021-09-30 22:00:00
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8431 non-null   int64
#  1   SO2            8431 non-null   float64
#  2   CO             8431 non-null   float64
#  3   O3             8431 non-null   float64
#  4   NO2            8431 non-null   float64
#  5   PM10           8431 non-null   float64
#  6   PM25           8431 non-null   float64
#  7   기온(°C)         8431 non-null   float64
#  8   강수량(mm)        8431 non-null   float64
#  9   풍속(m/s)        8431 non-null   float64
#  10  풍향(16방위)       8431 non-null   float64
#  11  습도(%)          8431 non-null   int64
#  12  증기압(hPa)       8431 non-null   float64
#  13  이슬점온도(°C)      8431 non-null   float64
#  14  현지기압(hPa)      8431 non-null   float64
#  15  해면기압(hPa)      8431 non-null   float64
#  16  일조(hr)         8431 non-null   float64
#  17  일사(MJ/m2)      8431 non-null   float64
#  18  적설(cm)         8431 non-null   float64
#  19  전운량(10분위)      8431 non-null   float64
#  20  중하층운량(10분위)    8431 non-null   int64
#  21  시정(10m)        8431 non-null   int64
#  22  지면온도(°C)       8431 non-null   float64
#  23  5cm 지중온도(°C)   8431 non-null   float64
#  24  10cm 지중온도(°C)  8431 non-null   float64
#  25  20cm 지중온도(°C)  8431 non-null   float64
#  26  30cm 지중온도(°C)  8431 non-null   float64
#  27  month          8431 non-null   int32
#  28  day            8431 non-null   int32
#  29  hour           8431 non-null   int32
#  30  PM10_lag1      8431 non-null   float64
#  31  PM10_1         8431 non-null   float64
# dtypes: float64(25), int32(3), int64(4)
# memory usage: 2.0 MB

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-8] train, test 데이터 분리</span>**

# %% [markdown]
# * 21년도 데이터(df_21)를 train 데이터로 저장하세요. y 값을 제외하고 train_x로 저장한 후 y 값은 train_y로 저장하세요.
# * 22년도 데이터(df_22)를 test 데이터로 저장하세요. y 값을 제외하고 test_x로 저장한 후 y 값은 test_y로 저장하세요.
# * 각각의 데이터프레임을 csv 파일로 저장하세요. (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
# * y값은 'PM10_1' 즉, t+1 시점의 미세먼지 농도입니다.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
train_x = df_21.drop('PM10_1', axis=1)
train_y = df_21['PM10_1']

test_x = df_22.drop('PM10_1', axis=1)
test_y = df_22['PM10_1']

# %%
# 각각의 데이터프레임을 csv 파일로 저장 (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
train_x.to_csv('data/train_x.csv', index=False)
train_y.to_csv('data/train_y.csv', index=False)
test_x.to_csv('data/test_x.csv', index=False)
test_y.to_csv('data/test_y.csv', index=False)
